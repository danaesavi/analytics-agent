# %%
import pandas as pd

df = pd.read_parquet("data/sample.parquet")
df.head()
# Out:
#    listing_id              neighbourhood        room_type   price  \
# 0       23500  Vesterbro-Kongens Enghave     Private room   655.0
# 1       29118  Vesterbro-Kongens Enghave  Entire home/apt   900.0
# 2       32841                   Østerbro  Entire home/apt   589.0
# 3       38499                   Indre By  Entire home/apt  2783.0
# 4       39055                Amager Vest  Entire home/apt  1829.0
#
#    availability_30  number_of_reviews  review_score last_review  \
# 0                1                 14          4.83  2025-09-21
# 1                7                 28          4.86  2025-07-25
# 2                0                  7          4.57  2016-09-15
# 3                0                 47          4.91  2025-08-31
# 4                1                125          4.83  2025-09-14
#
#    minimum_nights        city  is_superhost
# 0               2  copenhagen         False
# 1               7  copenhagen         False
# 2             100  copenhagen         False
# 3               5  copenhagen          True
# 4               2  copenhagen         False

# %%
print("shape")
print(df.shape)
print("columns")
print(df.columns)
print("price")
print(df["price"].describe(),"\n")
print("room_type")
print(df["room_type"].value_counts(),"\n")
print("availability_30")
print(df["availability_30"].describe(),"\n")
print("is_superhost")
print(df["is_superhost"].value_counts(),"\n")
# Out:
# shape
# (13307, 11)
# columns
# Index(['listing_id', 'neighbourhood', 'room_type', 'price', 'availability_30',
#        'number_of_reviews', 'review_score', 'last_review', 'minimum_nights',
#        'city', 'is_superhost'],
#       dtype='str')
# price
# count    13307.000000
# mean      1356.729766
# std        688.485515
# min        136.000000
# 25%        900.000000
# 50%       1200.000000
# 75%       1637.500000
# max       4896.000000
# Name: price, dtype: float64
#
# room_type
# room_type
# Entire home/apt    12168
# Private room        1119
# Shared room           17
# Hotel room             3
# Name: count, dtype: int64
#
# availability_30
# count    13307.000000
# mean         8.840761
# std         10.163778
# min          0.000000
# 25%          0.000000
# 50%          5.000000
# 75%         16.000000
# max         30.000000
# Name: availability_30, dtype: float64
#
# is_superhost
# is_superhost
# False    11284
# True      2023
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13307 entries, 0 to 13306
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   listing_id         13307 non-null  int64
#  1   neighbourhood      13307 non-null  str
#  2   room_type          13307 non-null  str
#  3   price              13307 non-null  float64
#  4   availability_30    13307 non-null  int64
#  5   number_of_reviews  13307 non-null  int64
#  6   review_score       11821 non-null  float64
#  7   last_review        11821 non-null  datetime64[us]
#  8   minimum_nights     13307 non-null  int64
#  9   city               13307 non-null  str
#  10  is_superhost       13307 non-null  bool
# dtypes: bool(1), datetime64[us](1), float64(2), int64(4), str(3)
# memory usage: 1.5 MB

# %%
df["neighbourhood"].unique()[:20]
# Out:
# <ArrowStringArray>
# ['Vesterbro-Kongens Enghave',                  'Østerbro',
#                   'Indre By',               'Amager Vest',
#                   'Nørrebro',             'Frederiksberg',
#                 'Bispebjerg',                     'Valby',
#                 'Amager Øst',                   'Vanløse',
#             'Brønshøj-Husum']
# Length: 11, dtype: str

# %%
df["neighbourhood"].value_counts()
# Out:
# neighbourhood
# Vesterbro-Kongens Enghave    2286
# Nørrebro                     2220
# Indre By                     2074
# Østerbro                     1447
# Frederiksberg                1402
# Amager Vest                  1225
# Amager Øst                   1020
# Bispebjerg                    595
# Valby                         475
# Vanløse                       331
# Brønshøj-Husum                232
# Name: count, dtype: int64
